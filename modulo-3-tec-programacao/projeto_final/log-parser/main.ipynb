# %%
# Parsear um log de servidor usando Pandas
# Lendo os arquivos: https://www.youtube.com/watch?v=O51VRHhKn5E

# %%
# Bibliotecas

import pandas as pd
import random
from parse import parse

# %%
#functions

def do_extract_sample(arquivo_entrada, arquivo_saida, recorte):
    with open(arquivo_entrada, 'r') as arquivo_grande:
        linhas = arquivo_grande.readlines()
        total_linhas = len(linhas)
        tamanho_amostra = int(total_linhas * recorte)
        amostra = random.sample(linhas, tamanho_amostra)
        with open(arquivo_saida, 'w') as arquivo_amostra:
            arquivo_amostra.writelines(amostra)
    return True

# %%
# Configuracoes

arquivo_original = 'arquivos\\access.log'

# %%
#separar o log em uma amostra menor pra fazer os testes
nome_saida = 'arquivos\\amostra.log'
percentual = 0.01

do_extract_sample(arquivo_original, nome_saida, percentual)
# Out:
# True

# %%
colunas_pandas = ['host', 'user_id', 'user_name', 'date_time', 'gmt', 'request', 'status', 'response_size', 'referer', 'user_agent', 'others']

nome_saida = 'arquivos\\amostra.log'

df = pd.read_csv(nome_saida, sep=' ', header=None, names=colunas_pandas, na_values='-', quotechar='"')

df['date_time'] = df['date_time'].srt.slice(1)
# Out:
#                   host  user_id  user_name              date_time     gmt  \
# 0        5.208.252.104      NaN        NaN  [22/Jan/2019:19:07:57  +0330]
# 1          5.74.57.168      NaN        NaN  [25/Jan/2019:19:00:57  +0330]
# 2         2.179.25.191      NaN        NaN  [23/Jan/2019:16:13:07  +0330]
# 3       213.217.50.233      NaN        NaN  [22/Jan/2019:06:53:36  +0330]
# 4        94.74.191.249      NaN        NaN  [22/Jan/2019:09:47:32  +0330]
# ...                ...      ...        ...                    ...     ...
# 103646   78.38.125.149      NaN        NaN  [23/Jan/2019:10:30:42  +0330]
# 103647   66.249.66.194      NaN        NaN  [23/Jan/2019:14:33:17  +0330]
# 103648  85.133.190.194      NaN        NaN  [22/Jan/2019:17:14:57  +0330]
# 103649  83.122.181.169      NaN        NaN  [24/Jan/2019:20:43:36  +0330]
# 103650    5.219.153.85      NaN        NaN  [24/Jan/2019:21:44:16  +0330]
#
#                                                   request  status  \
# 0       GET /image/34204?name=800d-18-55mm-1.jpg&wh=20...     200
# 1                             GET /settings/logo HTTP/1.1     200
# 2                  GET /image/14/productTypeType HTTP/1.1     200
# 3          GET /image/65019/productModel/100x100 HTTP/1.1     200
# 4          GET /static/css/font/wyekan/font.woff HTTP/1.1     200
# ...                                                   ...     ...
# 103646               GET /image/8764/specialSale HTTP/1.1     200
# 103647  GET /product/2529/%D8%B3%D8%B1%D8%AE-%DA%A9%D9...     302
# 103648  GET /static/images/guarantees/fastDelivery.png...     200
# 103649                      GET /image/131/brand HTTP/1.1     200
# 103650  GET /image/33968?wh=400x400&name=j6-ggg.jpg HT...     200
#
#         response_size                                            referer  \
# 0                6803                                                NaN
# 1                4120      https://www.zanbil.ir/m/filter/p62%2Cstexists
# 2               11129               https://www.zanbil.ir/filter/b888,p3
# 3                2850              https://www.zanbil.ir/filter/b113,p62
# 4               28536  https://znbl.ir/static/bundle-bundle_site_head...
# ...               ...                                                ...
# 103646          36734                             https://www.zanbil.ir/
# 103647              0                                                NaN
# 103648           7713                    https://www.zanbil.ir/filter/b8
# 103649           2599            https://www.zanbil.ir/m/filter/b99%2Cp5
# 103650           5336  https://www.zanbil.ir/product/33968/64756/%DA%...
#
#                                                user_agent others
# 0       Dalvik/2.1.0 (Linux; U; Android 6.0; ALE-L21 B...    NaN
# 1       Mozilla/5.0 (Linux; Android 4.2.2; MediaPad X1...    NaN
# 2       Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...    NaN
# 3       Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...    NaN
# 4       Mozilla/5.0 (Windows NT 5.1; rv:52.0) Gecko/20...    NaN
# ...                                                   ...    ...
# 103646  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...    NaN
# 103647  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...    NaN
# 103648  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...    NaN
# 103649  Mozilla/5.0 (Linux; Android 7.1.1; LG-M700) Ap...    NaN
# 103650  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...    NaN
#
# [103651 rows x 11 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21360\1308393946.py in ?()
#       3 nome_saida = 'arquivos\\amostra.log'
#       4
#       5 df = pd.read_csv(nome_saida, sep=' ', header=None, names=colunas_pandas, na_values='-', quotechar='"')
#       6
# ----> 7 df['date_time'] = df['date_time'].srt.slice(1)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'srt'
