# %% [markdown]
# ## O GIT
#
#
# https://git-scm.com/book/pt-br/v2/Come%C3%A7ando-Uma-Breve-Hist%C3%B3ria-do-Git

# %% [markdown]
# ## História
# <img src="data:image/jpeg;base64,..." />

# %% [markdown]
# # Intervalo, voltamos 20h51

# %% [markdown]
# Exemplo de commit x.0

# %% [markdown]
# ## Conceitos e Comandos
#
# https://docs.google.com/presentation/d/1KaVhdy-h7QpwNqWoWFaLFzla_ImXaOpSkD2nF6k2keg/edit#slide=id.p3

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ### Referência
#
# https://git-scm.com/book/pt-br/v2
