# %% [markdown]
# # Series
#
# O objeto fundamental do Pandas são as **Series**, uma classe do pandas.
#
# As Series são as **colunas das tabelas** (que veremos mais a frente), e por baixo dos panos, os dados ficam armazenados como **numpy arrays**!
#
# A diferença é que a série possui um **índice associado**, permitindo o acesso aos conteúdos dessa estrutura por ele, como um dicionário.
#
# Além disso, as séries têm métodos específicos além dos que vimos pra arrays, o que será super útil!
#
# Podemos criar uma série **a partir de uma lista**, usando a função do pandas `pd.Series()`:

# %%
import pandas as pd

# %%
lista = [4, 8, 9, 12]

serie = pd.Series(lista)
serie
# Out:
# 0     4
# 1     8
# 2     9
# 3    12
# dtype: int64

# %%
type(serie)
# Out:
# pandas.core.series.Series

# %%
serie.values
# Out:
# array([ 4,  8,  9, 12])

# %%
type(serie.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Indice acesso

# %%
serie[1]
# Out:
# 8

# %% [markdown]
# Valores

# %%
serie.values
# Out:
# array([ 4,  8,  9, 12])

# %% [markdown]
# Indice

# %%
serie.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Indice não numérico

# %%
lista = [4, 8, 9, 12]
indices = ['a', 'b', 'c', 'd']

# %%
serie = pd.Series(data=lista, index=indices)
serie
# Out:
# a     4
# b     8
# c     9
# d    12
# dtype: int64

# %%
serie[1]
# Out:
# /tmp/ipykernel_178916/844541441.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   serie[1]
# 8

# %%
serie.iloc[1]
# Out:
# 8

# %%
serie['b']
# Out:
# 8

# %% [markdown]
# Slicing

# %%
serie['b':'d']
# Out:
# b     8
# c     9
# d    12
# dtype: int64

# %%
serie.loc[['a', 'd']]
# Out:
# a     4
# d    12
# dtype: int64

# %% [markdown]
# Filtros

# %%
lista = [4, 8, 9, 12]
indices = ['a', 'b', 'c', 'd']
serie = pd.Series(data=lista, index=indices)
serie
# Out:
# a     4
# b     8
# c     9
# d    12
# dtype: int64

# %%
mascara = serie >= 9 
mascara
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
serie[mascara]
# Out:
# c     9
# d    12
# dtype: int64

# %% [markdown]
# Apply

# %%
lista = [4, 8, 9, 12]
indices = ['a', 'b', 'c', 'd']
serie = pd.Series(data=lista, index=indices)
serie
# Out:
# a     4
# b     8
# c     9
# d    12
# dtype: int64

# %%
def multiplicar_2(numero):
    return numero * 2

multiplicar_2(12)
# Out:
# 24

# %%
lmultiplicar_2 = lambda numero: numero * 2

lmultiplicar_2(13)
# Out:
# 26

# %%
serie.apply(multiplicar_2)
# Out:
# a     8
# b    16
# c    18
# d    24
# dtype: int64

# %%
serie.apply(lmultiplicar_2)
# Out:
# a     8
# b    16
# c    18
# d    24
# dtype: int64

# %% [markdown]
# Voltando novamente ao DataFrame

# %%
df = pd.read_csv('produtos.csv')
df.head()
# Out:
#      id      brand                  name  price price_sign currency  \
# 0  1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1  1047  colourpop           Blotted Lip    5.5          $      CAD
# 2  1046  colourpop           Lippie Stix    5.5          $      CAD
# 3  1045  colourpop  No Filter Foundation   12.0          $      CAD
# 4  1044      boosh              Lipstick   26.0          $      CAD
#
#                                           image_link  \
# 0  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 2  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 3  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 4  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                         product_link  \
# 0    https://colourpop.com/collections/lippie-pencil
# 1  https://colourpop.com/collections/lippie-stix?...
# 2      https://colourpop.com/collections/lippie-stix
# 3  https://colourpop.com/products/no-filter-matte...
# 4               https://www.boosh.ca/collections/all
#
#                                         website_link  \
# 0                              https://colourpop.com
# 1                              https://colourpop.com
# 2                              https://colourpop.com
# 3  https://colourpop.com/products/no-filter-matte...
# 4                              https://www.boosh.ca/
#
#                                          description  rating  category  \
# 0  Lippie Pencil A long-wearing and high-intensit...     NaN    pencil
# 1  Blotted Lip Sheer matte lipstick that creates ...     NaN  lipstick
# 2  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  lipstick
# 3  Developed for the Selfie Age, our buildable fu...     NaN    liquid
# 4  All of our products are free from lead and hea...     NaN  lipstick
#
#   product_type                      tag_list                created_at  \
# 0    lip_liner     ['cruelty free', 'Vegan']  2018-07-08T23:45:08.056Z
# 1     lipstick     ['cruelty free', 'Vegan']  2018-07-08T22:01:20.178Z
# 2     lipstick     ['cruelty free', 'Vegan']  2018-07-08T21:47:49.858Z
# 3   foundation     ['cruelty free', 'Vegan']  2018-07-08T18:22:25.273Z
# 4     lipstick  ['Chemical Free', 'Organic']  2018-07-08T17:32:28.088Z
#
#                  updated_at  \
# 0  2018-07-09T00:53:23.301Z
# 1  2018-07-09T00:53:23.287Z
# 2  2018-07-09T00:53:23.274Z
# 3  2018-07-09T00:53:23.313Z
# 4  2018-09-02T22:52:06.669Z
#
#                                      product_api_url  \
# 0  http://makeup-api.herokuapp.com/api/v1/product...
# 1  http://makeup-api.herokuapp.com/api/v1/product...
# 2  http://makeup-api.herokuapp.com/api/v1/product...
# 3  http://makeup-api.herokuapp.com/api/v1/product...
# 4  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                   api_featured_image  \
# 0  //s3.amazonaws.com/donovanbailey/products/api_...
# 1  //s3.amazonaws.com/donovanbailey/products/api_...
# 2  //s3.amazonaws.com/donovanbailey/products/api_...
# 3  //s3.amazonaws.com/donovanbailey/products/api_...
# 4  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                       product_colors
# 0  [{'hex_value': '#B28378', 'colour_name': 'BFF ...
# 1  [{'hex_value': '#b72227', 'colour_name': "Bee'...
# 2  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...
# 3  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...
# 4  [{'hex_value': '#CB4975', 'colour_name': 'Babs...

# %%
df.dtypes
# Out:
# id                      int64
# brand                  object
# name                   object
# price                 float64
# price_sign             object
# currency               object
# image_link             object
# product_link           object
# website_link           object
# description            object
# rating                float64
# category               object
# product_type           object
# tag_list               object
# created_at             object
# updated_at             object
# product_api_url        object
# api_featured_image     object
# product_colors         object
# dtype: object

# %%
type(df['price'])
# Out:
# pandas.core.series.Series

# %%
df['price'].max()
# Out:
# 77.0

# %%
df['price'].argmax()
# Out:
# 364

# %%
df['price'].mean() # Erro misturei USD, com outra moedas...
# Out:
# 16.508593238822247

# %%
df['price'].sort_values(ascending=False)
# Out:
# 364    77.00
# 386    75.00
# 329    65.00
# 689    60.00
# 676    56.49
#        ...
# 377      NaN
# 378      NaN
# 379      NaN
# 380      NaN
# 381      NaN
# Name: price, Length: 931, dtype: float64

# %%
df.sort_values(by=['price'], ascending=False)
# Out:
#       id     brand                                               name  price  \
# 364  662      dior                    Dior Holiday Couture Collection  77.00
# 386  639   benefit                 cheekathon bronzer & blush palette  75.00
# 329  697      dior                    Couture Colour Wardrobe palette  65.00
# 689  274  pacifica  Pacifica Natural Minerals Solar Complete Color...  60.00
# 676  287   mistura                     Mistura 6-in-1 Beauty Solution  56.49
# ..   ...       ...                                                ...    ...
# 377  649      iman                          Amplify Mascara Black Ink    NaN
# 378  648      iman              Perfect Eyebrow Pencil Blackest Brown    NaN
# 379  647      iman                           Perfect Eye Pencil Ebony    NaN
# 380  646      iman             Luxury Moisturizing Lipstick IMAN Nude    NaN
# 381  645      iman                        Luxury Eye Shadow Bejeweled    NaN
#
#     price_sign currency                                         image_link  \
# 364          £      GBP  https://www.dior.com/beauty/version-5.14327481...
# 386        NaN      NaN  https://www.benefitcosmetics.com/ca/sites/ca/f...
# 329          £      GBP  https://www.dior.com/beauty/version-5.14327481...
# 689        NaN      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/baf991...
# 676        NaN      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/d45c12...
# ..         ...      ...                                                ...
# 377        NaN      NaN  http://imancosmetics.com/resources/uploads/pro...
# 378        NaN      NaN  http://imancosmetics.com/resources/uploads/pro...
# 379        NaN      NaN  http://imancosmetics.com/resources/uploads/pro...
# 380        NaN      NaN  http://imancosmetics.com/resources/uploads/pro...
# 381        NaN      NaN  http://imancosmetics.com/resources/uploads/pro...
#
#                                           product_link  \
# 364  https://www.dior.com/beauty/en_gb/fragrance-be...
# 386  https://www.benefitcosmetics.com/ca/en-gb/prod...
# 329  https://www.dior.com/beauty/en_gb/fragrance-be...
# 689  https://well.ca/products/pacifica-natural-mine...
# 676  https://well.ca/products/mistura-6-in-1-beauty...
# ..                                                 ...
# 377  http://imancosmetics.com/shop/products/eyes/am...
# 378  http://imancosmetics.com/shop/products/eyes/br...
# 379  http://imancosmetics.com/shop/products/eyes/ey...
# 380  http://imancosmetics.com/shop/products/lips/li...
# 381  http://imancosmetics.com/shop/products/eyes/ey...
#
#                          website_link  \
# 364              https://www.dior.com
# 386  https://www.benefitcosmetics.com
# 329              https://www.dior.com
# 689                   https://well.ca
# 676                   https://well.ca
# ..                                ...
# 377         http://imancosmetics.com/
# 378         http://imancosmetics.com/
# 379         http://imancosmetics.com/
# 380         http://imancosmetics.com/
# 381         http://imancosmetics.com/
#
#                                            description  rating  category  \
# 364  A couture makeup bag with a selection of three...     NaN  lipstick
# 386                    “kick up your cheeks” blush kit     NaN       NaN
# 329  Directly inspired by runway shows, the Couture...     NaN   palette
# 689  All you need to look naturally gorgeous!  The ...     4.9       NaN
# 676  Mistura’s incredible 6-in-1 Beauty Solution po...     2.6       NaN
# ..                                                 ...     ...       ...
# 377  24oz (7g) Thickens, lengthens & separates lash...     NaN       NaN
# 378  0.05oz (1.5g) Versatile new product that combi...     NaN       NaN
# 379  0.05oz (1.5g) Expertly defines & lines eyes. M...     NaN    pencil
# 380  13oz (3.7g) Luscious creamy, semi-matte lip co...     NaN  lipstick
# 381  0.05oz (1.42g) Silky, long-lasting crease-resi...     NaN       NaN
#
#     product_type              tag_list                created_at  \
# 364     lipstick                    []  2017-12-03T23:21:53.130Z
# 386      bronzer                    []  2016-10-02T11:37:26.478Z
# 329    eyeshadow                    []  2017-12-03T23:22:53.414Z
# 689      bronzer  ['Vegan', 'Natural']  2016-10-01T18:30:02.836Z
# 676    eyeshadow          ['Canadian']  2016-10-01T18:30:21.480Z
# ..           ...                   ...                       ...
# 377      mascara                    []  2016-10-03T14:05:11.236Z
# 378      eyebrow                    []  2016-10-03T14:05:06.144Z
# 379     eyeliner                    []  2016-10-03T14:05:00.721Z
# 380     lipstick                    []  2016-10-03T14:04:54.792Z
# 381    eyeshadow                    []  2016-10-03T14:04:49.180Z
#
#                    updated_at  \
# 364  2017-12-23T20:58:42.309Z
# 386  2017-12-23T20:42:43.806Z
# 329  2017-12-26T00:33:00.563Z
# 689  2017-12-23T21:08:48.370Z
# 676  2017-12-23T21:08:14.685Z
# ..                        ...
# 377  2017-12-23T20:51:28.535Z
# 378  2017-12-23T20:51:28.352Z
# 379  2017-12-23T20:51:24.963Z
# 380  2017-12-23T20:51:22.894Z
# 381  2017-12-23T20:51:19.960Z
#
#                                        product_api_url  \
# 364  http://makeup-api.herokuapp.com/api/v1/product...
# 386  http://makeup-api.herokuapp.com/api/v1/product...
# 329  http://makeup-api.herokuapp.com/api/v1/product...
# 689  http://makeup-api.herokuapp.com/api/v1/product...
# 676  http://makeup-api.herokuapp.com/api/v1/product...
# ..                                                 ...
# 377  http://makeup-api.herokuapp.com/api/v1/product...
# 378  http://makeup-api.herokuapp.com/api/v1/product...
# 379  http://makeup-api.herokuapp.com/api/v1/product...
# 380  http://makeup-api.herokuapp.com/api/v1/product...
# 381  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                     api_featured_image  \
# 364  //s3.amazonaws.com/donovanbailey/products/api_...
# 386  //s3.amazonaws.com/donovanbailey/products/api_...
# 329  //s3.amazonaws.com/donovanbailey/products/api_...
# 689  //s3.amazonaws.com/donovanbailey/products/api_...
# 676  //s3.amazonaws.com/donovanbailey/products/api_...
# ..                                                 ...
# 377  //s3.amazonaws.com/donovanbailey/products/api_...
# 378  //s3.amazonaws.com/donovanbailey/products/api_...
# 379  //s3.amazonaws.com/donovanbailey/products/api_...
# 380  //s3.amazonaws.com/donovanbailey/products/api_...
# 381  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                         product_colors
# 364                                                 []
# 386                                                 []
# 329   [{'hex_value': '#C48A80', 'colour_name': '000'}]
# 689                                                 []
# 676  [{'hex_value': '#DBAA90', 'colour_name': 'colo...
# ..                                                 ...
# 377                                                 []
# 378                                                 []
# 379  [{'hex_value': '#283434', 'colour_name': 'Blac...
# 380  [{'hex_value': '#d27d56', 'colour_name': 'NEW ...
# 381  [{'hex_value': '#ffd9ac', 'colour_name': 'Whit...
#
# [931 rows x 19 columns]

# %%
df.sort_values(by=['brand'], ascending=False)
# Out:
#        id                 brand  \
# 7    1041  zorah biocosmetiques
# 8    1040  zorah biocosmetiques
# 759   191                 zorah
# 881    50                 zorah
# 658   305            wet n wild
# ..    ...                   ...
# 617   347                   NaN
# 731   227                   NaN
# 743   210                   NaN
# 910    21                   NaN
# 929     2                   NaN
#
#                                                   name  price price_sign  \
# 7                                         Liquid Liner   0.00          $
# 8                                            Eyeshadow   0.00          $
# 759                                 Zorah Liquid Liner  24.00        NaN
# 881                            Zorah Mascara Lengthing  27.00        NaN
# 658              Wet n Wild Color Icon Eyeshadow Trio    4.79        NaN
# ..                                                 ...    ...        ...
# 617                    DaLish Silk to Matte Foundation  44.00        NaN
# 731                 Earth Lab Vegan Mineral Eye Pencil  18.00        NaN
# 743  Pysicians Formula Eye Booster Cushion Liquid L...  15.99        NaN
# 910                              Earth Lab Raw Mascara  24.00        NaN
# 929                  L' Oreal Paris Voluminous Mascara   9.99        NaN
#
#     currency                                         image_link  \
# 7        USD  https://www.purpicks.com/wp-content/uploads/20...
# 8        USD  https://www.purpicks.com/wp-content/uploads/20...
# 759      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/3dc157...
# 881      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/dba243...
# 658      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/07ea2b...
# ..       ...                                                ...
# 617      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/e98af1...
# 731      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/e43ef1...
# 743      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/7edeec...
# 910      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/823cec...
# 929      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/4d671a...
#
#                                           product_link           website_link  \
# 7    https://www.purpicks.com/product/zorah-biocosm...  https://purpicks.com/
# 8    https://www.purpicks.com/product/zorah-eyeshadow/  https://purpicks.com/
# 759  https://well.ca/products/zorah-liquid-liner_99...        https://well.ca
# 881  https://well.ca/products/zorah-mascara-lengthi...        https://well.ca
# 658  https://well.ca/products/wet-n-wild-color-icon...        https://well.ca
# ..                                                 ...                    ...
# 617  https://well.ca/products/dalish-silk-to-matte-...        https://well.ca
# 731  https://well.ca/products/earth-lab-vegan-miner...        https://well.ca
# 743  https://well.ca/products/pysicians-formula-eye...        https://well.ca
# 910  https://well.ca/products/earth-lab-raw-mascara...        https://well.ca
# 929  https://well.ca/products/l-oreal-paris-volumin...        https://well.ca
#
#                                            description  rating category  \
# 7    <strong>12 hours of long-lasting</strong> inte...     NaN   liquid
# 8    <strong>Product Description</strong>Anti-aging...     NaN      NaN
# 759  Zorah Liquid Liner gives you 12 hours of long-...     3.3   liquid
# 881  This lengthening mascara is made with a unique...     4.8      NaN
# 658  This coordinating trio of shades takes the gue...     5.0      NaN
# ..                                                 ...     ...      ...
# 617  This long-wear DaLish foundation starts out si...     4.0   liquid
# 731  These natural minerals eye pencils are made fr...     3.4   pencil
# 743  Unique & Professional Cushion Eyeliner: Innova...     NaN   liquid
# 910  This 100% natural, botanical based formula gli...     4.1      NaN
# 929  Voluminous - Volume Building Waterproof Mascar...     4.5      NaN
#
#     product_type                                           tag_list  \
# 7       eyeliner                            ['purpicks', 'EcoCert']
# 8      eyeshadow                            ['purpicks', 'EcoCert']
# 759     eyeliner  ['Natural', 'Organic', 'Vegan', 'Gluten Free',...
# 881      mascara  ['Natural', 'Organic', 'Gluten Free', 'Canadian']
# 658    eyeshadow                                                 []
# ..           ...                                                ...
# 617   foundation                            ['Canadian', 'Natural']
# 731     eyeliner                   ['Natural', 'Vegan', 'Canadian']
# 743     eyeliner                         ['Gluten Free', 'Natural']
# 910      mascara                            ['Natural', 'Canadian']
# 929      mascara                                                 []
#
#                    created_at                updated_at  \
# 7    2018-06-30T19:19:32.312Z  2018-09-02T22:52:06.723Z
# 8    2018-06-30T19:19:32.252Z  2018-09-02T22:52:06.714Z
# 759  2016-10-01T18:28:07.638Z  2017-12-23T20:51:18.506Z
# 881  2016-10-01T18:11:43.566Z  2017-12-23T20:50:54.486Z
# 658  2016-10-01T18:30:53.725Z  2017-12-23T21:08:17.940Z
# ..                        ...                       ...
# 617  2016-10-01T18:32:11.060Z  2017-12-23T21:08:25.741Z
# 731  2016-10-01T18:28:52.926Z  2017-12-23T20:51:30.288Z
# 743  2016-10-01T18:28:31.363Z  2017-12-23T20:51:25.270Z
# 910  2016-10-01T18:11:10.938Z  2017-12-23T20:31:49.596Z
# 929  2016-10-01T18:10:49.185Z  2017-12-23T20:31:46.436Z
#
#                                        product_api_url  \
# 7    http://makeup-api.herokuapp.com/api/v1/product...
# 8    http://makeup-api.herokuapp.com/api/v1/product...
# 759  http://makeup-api.herokuapp.com/api/v1/product...
# 881  http://makeup-api.herokuapp.com/api/v1/product...
# 658  http://makeup-api.herokuapp.com/api/v1/product...
# ..                                                 ...
# 617  http://makeup-api.herokuapp.com/api/v1/product...
# 731  http://makeup-api.herokuapp.com/api/v1/product...
# 743  http://makeup-api.herokuapp.com/api/v1/product...
# 910  http://makeup-api.herokuapp.com/api/v1/product...
# 929  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                     api_featured_image  \
# 7    //s3.amazonaws.com/donovanbailey/products/api_...
# 8    //s3.amazonaws.com/donovanbailey/products/api_...
# 759  //s3.amazonaws.com/donovanbailey/products/api_...
# 881  //s3.amazonaws.com/donovanbailey/products/api_...
# 658  //s3.amazonaws.com/donovanbailey/products/api_...
# ..                                                 ...
# 617  //s3.amazonaws.com/donovanbailey/products/api_...
# 731  //s3.amazonaws.com/donovanbailey/products/api_...
# 743  //s3.amazonaws.com/donovanbailey/products/api_...
# 910  //s3.amazonaws.com/donovanbailey/products/api_...
# 929  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                         product_colors
# 7    [{'hex_value': '#000000', 'colour_name': 'Blac...
# 8    [{'hex_value': '#966A54', 'colour_name': 'Saha...
# 759  [{'hex_value': '#000000', 'colour_name': 'Blac...
# 881                                                 []
# 658                                                 []
# ..                                                 ...
# 617  [{'hex_value': '#edbc92', 'colour_name': 'F01 ...
# 731  [{'hex_value': '#322423', 'colour_name': 'Espr...
# 743                                                 []
# 910                                                 []
# 929  [{'hex_value': '#231F20', 'colour_name': 'Blac...
#
# [931 rows x 19 columns]

# %%
df.sort_values(by=['brand', 'name'], ascending=[False, True])
# Out:
#        id                 brand  \
# 8    1040  zorah biocosmetiques
# 7    1041  zorah biocosmetiques
# 759   191                 zorah
# 881    50                 zorah
# 681   282            wet n wild
# ..    ...                   ...
# 503   475                   NaN
# 929     2                   NaN
# 743   210                   NaN
# 509   469                   NaN
# 473   507                   NaN
#
#                                                   name  price price_sign  \
# 8                                            Eyeshadow   0.00          $
# 7                                         Liquid Liner   0.00          $
# 759                                 Zorah Liquid Liner  24.00        NaN
# 881                            Zorah Mascara Lengthing  27.00        NaN
# 681        Wet n Wild Color Icon Eye Shadow Collection   4.99        NaN
# ..                                                 ...    ...        ...
# 503                      Fake Bake Blush Legal Sunburn  15.99        NaN
# 929                  L' Oreal Paris Voluminous Mascara   9.99        NaN
# 743  Pysicians Formula Eye Booster Cushion Liquid L...  15.99        NaN
# 509                              Saint Cosmetics Blush  28.96        NaN
# 473                            Saint Cosmetics Bronzer  30.96        NaN
#
#     currency                                         image_link  \
# 8        USD  https://www.purpicks.com/wp-content/uploads/20...
# 7        USD  https://www.purpicks.com/wp-content/uploads/20...
# 759      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/3dc157...
# 881      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/dba243...
# 681      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/9c602a...
# ..       ...                                                ...
# 503      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/a20f36...
# 929      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/4d671a...
# 743      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/7edeec...
# 509      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/ed6e23...
# 473      NaN  https://d3t32hsnjxo7q6.cloudfront.net/i/4f8578...
#
#                                           product_link           website_link  \
# 8    https://www.purpicks.com/product/zorah-eyeshadow/  https://purpicks.com/
# 7    https://www.purpicks.com/product/zorah-biocosm...  https://purpicks.com/
# 759  https://well.ca/products/zorah-liquid-liner_99...        https://well.ca
# 881  https://well.ca/products/zorah-mascara-lengthi...        https://well.ca
# 681  https://well.ca/products/wet-n-wild-color-icon...        https://well.ca
# ..                                                 ...                    ...
# 503  https://well.ca/products/fake-bake-blush-legal...        https://well.ca
# 929  https://well.ca/products/l-oreal-paris-volumin...        https://well.ca
# 743  https://well.ca/products/pysicians-formula-eye...        https://well.ca
# 509  https://well.ca/products/saint-cosmetics-blush...        https://well.ca
# 473  https://well.ca/products/saint-cosmetics-bronz...        https://well.ca
#
#                                            description  rating category  \
# 8    <strong>Product Description</strong>Anti-aging...     NaN      NaN
# 7    <strong>12 hours of long-lasting</strong> inte...     NaN   liquid
# 759  Zorah Liquid Liner gives you 12 hours of long-...     3.3   liquid
# 881  This lengthening mascara is made with a unique...     4.8      NaN
# 681  Eight dynamic, perfectly color-coordinated sha...     4.2  palette
# ..                                                 ...     ...      ...
# 503  Give your cheeks a sun kissed glow with Fake B...     5.0   powder
# 929  Voluminous - Volume Building Waterproof Mascar...     4.5      NaN
# 743  Unique & Professional Cushion Eyeliner: Innova...     NaN   liquid
# 509  Create naturally flushed looking cheeks with S...     NaN   powder
# 473  Saint Cosmetics' velvety smooth bronzing formu...     NaN      NaN
#
#     product_type                                           tag_list  \
# 8      eyeshadow                            ['purpicks', 'EcoCert']
# 7       eyeliner                            ['purpicks', 'EcoCert']
# 759     eyeliner  ['Natural', 'Organic', 'Vegan', 'Gluten Free',...
# 881      mascara  ['Natural', 'Organic', 'Gluten Free', 'Canadian']
# 681    eyeshadow                                                 []
# ..           ...                                                ...
# 503        blush                                                 []
# 929      mascara                                                 []
# 743     eyeliner                         ['Gluten Free', 'Natural']
# 509        blush    ['Natural', 'Vegan', 'Gluten Free', 'Canadian']
# 473      bronzer    ['Natural', 'Vegan', 'Gluten Free', 'Canadian']
#
#                    created_at                updated_at  \
# 8    2018-06-30T19:19:32.252Z  2018-09-02T22:52:06.714Z
# 7    2018-06-30T19:19:32.312Z  2018-09-02T22:52:06.723Z
# 759  2016-10-01T18:28:07.638Z  2017-12-23T20:51:18.506Z
# 881  2016-10-01T18:11:43.566Z  2017-12-23T20:50:54.486Z
# 681  2016-10-01T18:30:15.859Z  2017-12-26T00:39:05.163Z
# ..                        ...                       ...
# 503  2016-10-01T18:35:36.689Z  2017-12-23T21:08:47.614Z
# 929  2016-10-01T18:10:49.185Z  2017-12-23T20:31:46.436Z
# 743  2016-10-01T18:28:31.363Z  2017-12-23T20:51:25.270Z
# 509  2016-10-01T18:35:28.524Z  2017-12-23T21:08:42.899Z
# 473  2016-10-01T18:36:30.602Z  2017-12-23T21:08:52.329Z
#
#                                        product_api_url  \
# 8    http://makeup-api.herokuapp.com/api/v1/product...
# 7    http://makeup-api.herokuapp.com/api/v1/product...
# 759  http://makeup-api.herokuapp.com/api/v1/product...
# 881  http://makeup-api.herokuapp.com/api/v1/product...
# 681  http://makeup-api.herokuapp.com/api/v1/product...
# ..                                                 ...
# 503  http://makeup-api.herokuapp.com/api/v1/product...
# 929  http://makeup-api.herokuapp.com/api/v1/product...
# 743  http://makeup-api.herokuapp.com/api/v1/product...
# 509  http://makeup-api.herokuapp.com/api/v1/product...
# 473  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                     api_featured_image  \
# 8    //s3.amazonaws.com/donovanbailey/products/api_...
# 7    //s3.amazonaws.com/donovanbailey/products/api_...
# 759  //s3.amazonaws.com/donovanbailey/products/api_...
# 881  //s3.amazonaws.com/donovanbailey/products/api_...
# 681  //s3.amazonaws.com/donovanbailey/products/api_...
# ..                                                 ...
# 503  //s3.amazonaws.com/donovanbailey/products/api_...
# 929  //s3.amazonaws.com/donovanbailey/products/api_...
# 743  //s3.amazonaws.com/donovanbailey/products/api_...
# 509  //s3.amazonaws.com/donovanbailey/products/api_...
# 473  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                         product_colors
# 8    [{'hex_value': '#966A54', 'colour_name': 'Saha...
# 7    [{'hex_value': '#000000', 'colour_name': 'Blac...
# 759  [{'hex_value': '#000000', 'colour_name': 'Blac...
# 881                                                 []
# 681                                                 []
# ..                                                 ...
# 503                                                 []
# 929  [{'hex_value': '#231F20', 'colour_name': 'Blac...
# 743                                                 []
# 509  [{'hex_value': '#F591A6', 'colour_name': 'Chee...
# 473  [{'hex_value': '#B77C59', 'colour_name': 'Glow...
#
# [931 rows x 19 columns]

# %%
df['brand'].unique()
# Out:
# array(['colourpop', 'boosh', 'deciem', 'zorah biocosmetiques',
#        'w3llpeople', "sally b's skin yummies", 'rejuva minerals',
#        'penny lane organics', 'nudus', 'marienatie',
#        "maia's mineral galaxy", 'lotus cosmetics usa', 'green people',
#        'coastal classic creation', "c'est moi", 'alva', 'glossier', 'nyx',
#        'fenty', 'clinique', 'dior', 'iman', 'benefit', 'smashbox',
#        'marcelle', 'stila', 'mineral fusion', nan, 'annabelle',
#        'dr. hauschka', 'physicians formula', 'cargo cosmetics',
#        'covergirl', 'e.l.f.', 'maybelline', 'almay', 'milani',
#        'pure anada', "l'oreal", 'sante', 'revlon', 'anna sui',
#        'wet n wild', 'pacifica', 'mistura', 'zorah', 'suncoat', 'moov',
#        'misa', 'salon perfect', 'orly', 'china glaze', 'essie',
#        'butter london', 'sinful colours', 'piggy paint', 'dalish',
#        "burt's bees"], dtype=object)

# %%
df['price'].value_counts()
# Out:
# price
# 10.99    42
# 0.00     40
# 9.99     33
# 10.00    29
# 7.00     28
#          ..
# 38.50     1
# 46.99     1
# 52.00     1
# 55.00     1
# 23.49     1
# Name: count, Length: 157, dtype: int64

# %%
df['price'].value_counts(normalize=True)
# Out:
# price
# 10.99    0.045802
# 0.00     0.043621
# 9.99     0.035987
# 10.00    0.031625
# 7.00     0.030534
#            ...
# 38.50    0.001091
# 46.99    0.001091
# 52.00    0.001091
# 55.00    0.001091
# 23.49    0.001091
# Name: proportion, Length: 157, dtype: float64

# %%
df.shape
# Out:
# (931, 19)

# %%
df['price'].size
# Out:
# 931

# %%
df['price'].value_counts() / df['price'].size
# Out:
# price
# 10.99    0.045113
# 0.00     0.042965
# 9.99     0.035446
# 10.00    0.031149
# 7.00     0.030075
#            ...
# 38.50    0.001074
# 46.99    0.001074
# 52.00    0.001074
# 55.00    0.001074
# 23.49    0.001074
# Name: count, Length: 157, dtype: float64

# %%
42 / 931
# Out:
# 0.045112781954887216

# %% [markdown]
# Criando Coluna

# %%
media_preco = df['price'].mean()
media_preco
# Out:
# 16.508593238822247

# %%
df['preco_acima_media'] = df['price'] > media_preco

# %%
df[['id', 'brand', 'name', 'price', 'preco_acima_media']].tail()
# Out:
#      id               brand  \
# 926   5            pacifica
# 927   4  physicians formula
# 928   3  physicians formula
# 929   2                 NaN
# 930   1          pure anada
#
#                                                   name  price  \
# 926  Pacifica Stellar Gaze Length & Strength Minera...  28.00
# 927    Physicians Formula Organic Wear FakeOut Mascara  15.79
# 928  Physicians Formula Organic Wear Lash Boosting ...  15.79
# 929                  L' Oreal Paris Voluminous Mascara   9.99
# 930                         Pure Anada Natural Mascara  14.00
#
#      preco_acima_media
# 926               True
# 927              False
# 928              False
# 929              False
# 930              False

# %% [markdown]
# Apagando coluna

# %%
df.drop(columns=['image_link', 'product_link', 'website_link'])
# Out:
#        id               brand  \
# 0    1048           colourpop
# 1    1047           colourpop
# 2    1046           colourpop
# 3    1045           colourpop
# 4    1044               boosh
# ..    ...                 ...
# 926     5            pacifica
# 927     4  physicians formula
# 928     3  physicians formula
# 929     2                 NaN
# 930     1          pure anada
#
#                                                   name  price price_sign  \
# 0                                        Lippie Pencil   5.00          $
# 1                                          Blotted Lip   5.50          $
# 2                                          Lippie Stix   5.50          $
# 3                                 No Filter Foundation  12.00          $
# 4                                             Lipstick  26.00          $
# ..                                                 ...    ...        ...
# 926  Pacifica Stellar Gaze Length & Strength Minera...  28.00        NaN
# 927    Physicians Formula Organic Wear FakeOut Mascara  15.79        NaN
# 928  Physicians Formula Organic Wear Lash Boosting ...  15.79        NaN
# 929                  L' Oreal Paris Voluminous Mascara   9.99        NaN
# 930                         Pure Anada Natural Mascara  14.00        NaN
#
#     currency                                        description  rating  \
# 0        CAD  Lippie Pencil A long-wearing and high-intensit...     NaN
# 1        CAD  Blotted Lip Sheer matte lipstick that creates ...     NaN
# 2        CAD  Lippie Stix Formula contains Vitamin E, Mango,...     NaN
# 3        CAD  Developed for the Selfie Age, our buildable fu...     NaN
# 4        CAD  All of our products are free from lead and hea...     NaN
# ..       ...                                                ...     ...
# 926      NaN  You will fall in love with Pacifica's long las...     4.2
# 927      NaN  Physicians Formula Organic Wear FakeOut Mascar...     3.9
# 928      NaN  Physicians Formula Organic Wear Lash Boosting ...     3.7
# 929      NaN  Voluminous - Volume Building Waterproof Mascar...     4.5
# 930      NaN  Finally, a natural mascara you can feel good a...     4.6
#
#      category product_type                                tag_list  \
# 0      pencil    lip_liner               ['cruelty free', 'Vegan']
# 1    lipstick     lipstick               ['cruelty free', 'Vegan']
# 2    lipstick     lipstick               ['cruelty free', 'Vegan']
# 3      liquid   foundation               ['cruelty free', 'Vegan']
# 4    lipstick     lipstick            ['Chemical Free', 'Organic']
# ..        ...          ...                                     ...
# 926       NaN      mascara                    ['Natural', 'Vegan']
# 927       NaN      mascara              ['Natural', 'Gluten Free']
# 928       NaN      mascara              ['Natural', 'Gluten Free']
# 929       NaN      mascara                                      []
# 930       NaN      mascara  ['Natural', 'Gluten Free', 'Canadian']
#
#                    created_at                updated_at  \
# 0    2018-07-08T23:45:08.056Z  2018-07-09T00:53:23.301Z
# 1    2018-07-08T22:01:20.178Z  2018-07-09T00:53:23.287Z
# 2    2018-07-08T21:47:49.858Z  2018-07-09T00:53:23.274Z
# 3    2018-07-08T18:22:25.273Z  2018-07-09T00:53:23.313Z
# 4    2018-07-08T17:32:28.088Z  2018-09-02T22:52:06.669Z
# ..                        ...                       ...
# 926  2016-10-01T18:10:52.756Z  2017-12-23T20:31:47.230Z
# 927  2016-10-01T18:10:51.387Z  2017-12-23T20:31:47.075Z
# 928  2016-10-01T18:10:50.417Z  2017-12-23T20:31:46.951Z
# 929  2016-10-01T18:10:49.185Z  2017-12-23T20:31:46.436Z
# 930  2016-10-01T18:10:46.893Z  2017-12-23T20:31:46.013Z
#
#                                        product_api_url  \
# 0    http://makeup-api.herokuapp.com/api/v1/product...
# 1    http://makeup-api.herokuapp.com/api/v1/product...
# 2    http://makeup-api.herokuapp.com/api/v1/product...
# 3    http://makeup-api.herokuapp.com/api/v1/product...
# 4    http://makeup-api.herokuapp.com/api/v1/product...
# ..                                                 ...
# 926  http://makeup-api.herokuapp.com/api/v1/product...
# 927  http://makeup-api.herokuapp.com/api/v1/product...
# 928  http://makeup-api.herokuapp.com/api/v1/product...
# 929  http://makeup-api.herokuapp.com/api/v1/product...
# 930  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                     api_featured_image  \
# 0    //s3.amazonaws.com/donovanbailey/products/api_...
# 1    //s3.amazonaws.com/donovanbailey/products/api_...
# 2    //s3.amazonaws.com/donovanbailey/products/api_...
# 3    //s3.amazonaws.com/donovanbailey/products/api_...
# 4    //s3.amazonaws.com/donovanbailey/products/api_...
# ..                                                 ...
# 926  //s3.amazonaws.com/donovanbailey/products/api_...
# 927  //s3.amazonaws.com/donovanbailey/products/api_...
# 928  //s3.amazonaws.com/donovanbailey/products/api_...
# 929  //s3.amazonaws.com/donovanbailey/products/api_...
# 930  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                         product_colors  preco_acima_media
# 0    [{'hex_value': '#B28378', 'colour_name': 'BFF ...              False
# 1    [{'hex_value': '#b72227', 'colour_name': "Bee'...              False
# 2    [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 3    [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 4    [{'hex_value': '#CB4975', 'colour_name': 'Babs...               True
# ..                                                 ...                ...
# 926                                                 []               True
# 927  [{'hex_value': '#000000', 'colour_name': 'Ultr...              False
# 928  [{'hex_value': '#000000', 'colour_name': 'Ultr...              False
# 929  [{'hex_value': '#231F20', 'colour_name': 'Blac...              False
# 930  [{'hex_value': '#000000', 'colour_name': 'Blac...              False
#
# [931 rows x 17 columns]

# %%
df.head()
# Out:
#      id      brand                  name  price price_sign currency  \
# 0  1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1  1047  colourpop           Blotted Lip    5.5          $      CAD
# 2  1046  colourpop           Lippie Stix    5.5          $      CAD
# 3  1045  colourpop  No Filter Foundation   12.0          $      CAD
# 4  1044      boosh              Lipstick   26.0          $      CAD
#
#                                           image_link  \
# 0  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 2  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 3  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 4  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                         product_link  \
# 0    https://colourpop.com/collections/lippie-pencil
# 1  https://colourpop.com/collections/lippie-stix?...
# 2      https://colourpop.com/collections/lippie-stix
# 3  https://colourpop.com/products/no-filter-matte...
# 4               https://www.boosh.ca/collections/all
#
#                                         website_link  \
# 0                              https://colourpop.com
# 1                              https://colourpop.com
# 2                              https://colourpop.com
# 3  https://colourpop.com/products/no-filter-matte...
# 4                              https://www.boosh.ca/
#
#                                          description  rating  category  \
# 0  Lippie Pencil A long-wearing and high-intensit...     NaN    pencil
# 1  Blotted Lip Sheer matte lipstick that creates ...     NaN  lipstick
# 2  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  lipstick
# 3  Developed for the Selfie Age, our buildable fu...     NaN    liquid
# 4  All of our products are free from lead and hea...     NaN  lipstick
#
#   product_type                      tag_list                created_at  \
# 0    lip_liner     ['cruelty free', 'Vegan']  2018-07-08T23:45:08.056Z
# 1     lipstick     ['cruelty free', 'Vegan']  2018-07-08T22:01:20.178Z
# 2     lipstick     ['cruelty free', 'Vegan']  2018-07-08T21:47:49.858Z
# 3   foundation     ['cruelty free', 'Vegan']  2018-07-08T18:22:25.273Z
# 4     lipstick  ['Chemical Free', 'Organic']  2018-07-08T17:32:28.088Z
#
#                  updated_at  \
# 0  2018-07-09T00:53:23.301Z
# 1  2018-07-09T00:53:23.287Z
# 2  2018-07-09T00:53:23.274Z
# 3  2018-07-09T00:53:23.313Z
# 4  2018-09-02T22:52:06.669Z
#
#                                      product_api_url  \
# 0  http://makeup-api.herokuapp.com/api/v1/product...
# 1  http://makeup-api.herokuapp.com/api/v1/product...
# 2  http://makeup-api.herokuapp.com/api/v1/product...
# 3  http://makeup-api.herokuapp.com/api/v1/product...
# 4  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                   api_featured_image  \
# 0  //s3.amazonaws.com/donovanbailey/products/api_...
# 1  //s3.amazonaws.com/donovanbailey/products/api_...
# 2  //s3.amazonaws.com/donovanbailey/products/api_...
# 3  //s3.amazonaws.com/donovanbailey/products/api_...
# 4  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                       product_colors  preco_acima_media
# 0  [{'hex_value': '#B28378', 'colour_name': 'BFF ...              False
# 1  [{'hex_value': '#b72227', 'colour_name': "Bee'...              False
# 2  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 3  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 4  [{'hex_value': '#CB4975', 'colour_name': 'Babs...               True

# %%
# df.drop(columns=['image_link', 'product_link', 'website_link'], inplace=True) # Ou
df = df.drop(columns=['image_link', 'product_link', 'website_link'])

df.head()
# Out:
#      id      brand                  name  price price_sign currency  \
# 0  1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1  1047  colourpop           Blotted Lip    5.5          $      CAD
# 2  1046  colourpop           Lippie Stix    5.5          $      CAD
# 3  1045  colourpop  No Filter Foundation   12.0          $      CAD
# 4  1044      boosh              Lipstick   26.0          $      CAD
#
#                                          description  rating  category  \
# 0  Lippie Pencil A long-wearing and high-intensit...     NaN    pencil
# 1  Blotted Lip Sheer matte lipstick that creates ...     NaN  lipstick
# 2  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  lipstick
# 3  Developed for the Selfie Age, our buildable fu...     NaN    liquid
# 4  All of our products are free from lead and hea...     NaN  lipstick
#
#   product_type                      tag_list                created_at  \
# 0    lip_liner     ['cruelty free', 'Vegan']  2018-07-08T23:45:08.056Z
# 1     lipstick     ['cruelty free', 'Vegan']  2018-07-08T22:01:20.178Z
# 2     lipstick     ['cruelty free', 'Vegan']  2018-07-08T21:47:49.858Z
# 3   foundation     ['cruelty free', 'Vegan']  2018-07-08T18:22:25.273Z
# 4     lipstick  ['Chemical Free', 'Organic']  2018-07-08T17:32:28.088Z
#
#                  updated_at  \
# 0  2018-07-09T00:53:23.301Z
# 1  2018-07-09T00:53:23.287Z
# 2  2018-07-09T00:53:23.274Z
# 3  2018-07-09T00:53:23.313Z
# 4  2018-09-02T22:52:06.669Z
#
#                                      product_api_url  \
# 0  http://makeup-api.herokuapp.com/api/v1/product...
# 1  http://makeup-api.herokuapp.com/api/v1/product...
# 2  http://makeup-api.herokuapp.com/api/v1/product...
# 3  http://makeup-api.herokuapp.com/api/v1/product...
# 4  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                   api_featured_image  \
# 0  //s3.amazonaws.com/donovanbailey/products/api_...
# 1  //s3.amazonaws.com/donovanbailey/products/api_...
# 2  //s3.amazonaws.com/donovanbailey/products/api_...
# 3  //s3.amazonaws.com/donovanbailey/products/api_...
# 4  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                       product_colors  preco_acima_media
# 0  [{'hex_value': '#B28378', 'colour_name': 'BFF ...              False
# 1  [{'hex_value': '#b72227', 'colour_name': "Bee'...              False
# 2  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 3  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 4  [{'hex_value': '#CB4975', 'colour_name': 'Babs...               True

# %%
produtos_preco_entre_muito_baratos = df['price'].between(1, 5)

df[produtos_preco_entre_muito_baratos].head()
# Out:
#       id      brand                   name  price price_sign currency  \
# 0   1048  colourpop          Lippie Pencil   5.00          $      CAD
# 75   973        nyx    Auto Eyebrow Pencil   4.75          $      USD
# 89   959        nyx        Slim Eye Pencil   4.00          $      USD
# 90   958        nyx  Retractable Eye Liner   5.00          $      USD
# 92   956        nyx       Jumbo Eye Pencil   4.50          $      USD
#
#                                           description  rating category  \
# 0   Lippie Pencil A long-wearing and high-intensit...     NaN   pencil
# 75  Create flawless arches with this eyebrow penci...     NaN      NaN
# 89  Slim, trim, but never prim. Our Slim Eye Penci...     NaN   pencil
# 90  Twist and shout! Renowned for its extreme last...     NaN   pencil
# 92                                                NaN     NaN   pencil
#
#    product_type                   tag_list                created_at  \
# 0     lip_liner  ['cruelty free', 'Vegan']  2018-07-08T23:45:08.056Z
# 75      eyebrow                         []  2017-12-24T02:32:34.961Z
# 89     eyeliner                         []  2017-12-24T02:32:09.470Z
# 90     eyeliner                         []  2017-12-24T02:32:05.574Z
# 92     eyeliner                         []  2017-12-24T02:31:53.675Z
#
#                   updated_at  \
# 0   2018-07-09T00:53:23.301Z
# 75  2017-12-24T02:32:35.432Z
# 89  2017-12-24T02:32:10.343Z
# 90  2017-12-24T02:32:06.056Z
# 92  2017-12-24T02:31:54.390Z
#
#                                       product_api_url  \
# 0   http://makeup-api.herokuapp.com/api/v1/product...
# 75  http://makeup-api.herokuapp.com/api/v1/product...
# 89  http://makeup-api.herokuapp.com/api/v1/product...
# 90  http://makeup-api.herokuapp.com/api/v1/product...
# 92  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                    api_featured_image  \
# 0   //s3.amazonaws.com/donovanbailey/products/api_...
# 75  //s3.amazonaws.com/donovanbailey/products/api_...
# 89  //s3.amazonaws.com/donovanbailey/products/api_...
# 90  //s3.amazonaws.com/donovanbailey/products/api_...
# 92  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                        product_colors  preco_acima_media
# 0   [{'hex_value': '#B28378', 'colour_name': 'BFF ...              False
# 75  [{'hex_value': '#B8957F', 'colour_name': 'Ligh...              False
# 89  [{'hex_value': '#9BC98B', 'colour_name': 'Gree...              False
# 90  [{'hex_value': '#776F26', 'colour_name': 'Gold...              False
# 92  [{'hex_value': '#FFACC1', 'colour_name': 'Stra...              False

# %% [markdown]
# ##### Projeto ideias
# - Percorrer o diretório pegando todas as figuras, processando augmentos e salvando as figuras
# - Percorrer o diretório pegando todos os áudios mp3, tirando os metadados: criando no final um csv ['nome_arquivo', 'taxa...']
# - Percorrer um arquivo de log, separar em um csv ['data', 'tipo (ex. Error, Warning, Info, etc)', 'texto do log']
#     - Análise dias da semana que temos mais erros, período do dia que temos mais erros, etc
# - Escolher um dataset para:
#     -  tratar os dados, dados faltantes
#     -  separar em csv/tabelas ex. produtos_baratos.csv e produtos_caros.csv
#
# ##### Criar um indice de técnicas/dicas/etc
# ##### Indicar na célula a técnicas/dicas/etc utilizada
# ##### Colocar no github

# %%
cotacao_dolar = 4.98

# %%
df['preco_reais'] = df['price'] * cotacao_dolar
df[['id', 'brand', 'name', 'price', 'preco_reais']].head()
# Out:
#      id      brand                  name  price  preco_reais
# 0  1048  colourpop         Lippie Pencil    5.0        24.90
# 1  1047  colourpop           Blotted Lip    5.5        27.39
# 2  1046  colourpop           Lippie Stix    5.5        27.39
# 3  1045  colourpop  No Filter Foundation   12.0        59.76
# 4  1044      boosh              Lipstick   26.0       129.48

# %%
df = df.rename(
    columns={
        'price':  'price_dollar',
        'preco_reais': 'preco_br'
    })
df[['id', 'brand', 'name', 'price_dollar', 'preco_br']].head()
# Out:
#      id      brand                  name  price_dollar  preco_br
# 0  1048  colourpop         Lippie Pencil           5.0     24.90
# 1  1047  colourpop           Blotted Lip           5.5     27.39
# 2  1046  colourpop           Lippie Stix           5.5     27.39
# 3  1045  colourpop  No Filter Foundation          12.0     59.76
# 4  1044      boosh              Lipstick          26.0    129.48

# %% [markdown]
# ## NaN
# Tem como base o https://en.wikipedia.org/wiki/IEEE_754
# Resumindo: NaN é um valor de ponto flutuante especial que não pode ser convertido em nenhum outro tipo de dado além do próprio float

# %%
import numpy as np

# %%
notas_provas = pd.DataFrame({
    'nome': ['A', 'B', 'C', 'D', 'E'],
    'nota': [85, np.nan, 95, 78, np.nan]
})
notas_provas
# Out:
#   nome  nota
# 0    A  85.0
# 1    B   NaN
# 2    C  95.0
# 3    D  78.0
# 4    E   NaN

# %%
notas_provas['nota'].mean()
# Out:
# 86.0

# %%
(85 + 95 + 78) / 3
# Out:
# 86.0

# %%
notas_provas.shape[0]
# Out:
# 5

# %%
notas_provas['nota'].sum() / notas_provas.shape[0]
# Out:
# 51.6

# %%
df['rating'].isna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# Name: rating, Length: 931, dtype: bool

# %%
df[df['rating'].isna()]
# Out:
#        id       brand                                               name  \
# 0    1048   colourpop                                      Lippie Pencil
# 1    1047   colourpop                                        Blotted Lip
# 2    1046   colourpop                                        Lippie Stix
# 3    1045   colourpop                               No Filter Foundation
# 4    1044       boosh                                           Lipstick
# ..    ...         ...                                                ...
# 878    53   covergirl  CoverGirl Professional Mascara Curved Brush Ve...
# 879    52   covergirl  CoverGirl Professional Mascara Curved Brush Bl...
# 890    41     l'oreal        L'Oreal Paris Voluminous Butterfly Mascara
# 891    40   covergirl  CoverGirl Professional Waterproof Mascara Very...
# 920    11  maybelline       Maybelline Volum' Express The Rocket Mascara
#
#      price_dollar price_sign currency  \
# 0            5.00          $      CAD
# 1            5.50          $      CAD
# 2            5.50          $      CAD
# 3           12.00          $      CAD
# 4           26.00          $      CAD
# ..            ...        ...      ...
# 878          6.99        NaN      NaN
# 879          6.99        NaN      NaN
# 890         13.49        NaN      NaN
# 891          6.99        NaN      NaN
# 920         10.99        NaN      NaN
#
#                                            description  rating  category  \
# 0    Lippie Pencil A long-wearing and high-intensit...     NaN    pencil
# 1    Blotted Lip Sheer matte lipstick that creates ...     NaN  lipstick
# 2    Lippie Stix Formula contains Vitamin E, Mango,...     NaN  lipstick
# 3    Developed for the Selfie Age, our buildable fu...     NaN    liquid
# 4    All of our products are free from lead and hea...     NaN  lipstick
# ..                                                 ...     ...       ...
# 878  Volumize, lengthen and define like a pro! Cove...     NaN       NaN
# 879  Volumize, lengthen and define like a pro! Cove...     NaN       NaN
# 890  Stretch and extend your lashes like wings!  In...     NaN       NaN
# 891  Volumize, lengthen and define like a pro! Cove...     NaN       NaN
# 920  Explosive Volume in Rocket Time! 8X Bigger, Sm...     NaN       NaN
#
#     product_type                      tag_list                created_at  \
# 0      lip_liner     ['cruelty free', 'Vegan']  2018-07-08T23:45:08.056Z
# 1       lipstick     ['cruelty free', 'Vegan']  2018-07-08T22:01:20.178Z
# 2       lipstick     ['cruelty free', 'Vegan']  2018-07-08T21:47:49.858Z
# 3     foundation     ['cruelty free', 'Vegan']  2018-07-08T18:22:25.273Z
# 4       lipstick  ['Chemical Free', 'Organic']  2018-07-08T17:32:28.088Z
# ..           ...                           ...                       ...
# 878      mascara                            []  2016-10-01T18:11:48.408Z
# 879      mascara                            []  2016-10-01T18:11:46.356Z
# 890      mascara                            []  2016-10-01T18:11:33.681Z
# 891      mascara                            []  2016-10-01T18:11:32.686Z
# 920      mascara                            []  2016-10-01T18:10:58.856Z
#
#                    updated_at  \
# 0    2018-07-09T00:53:23.301Z
# 1    2018-07-09T00:53:23.287Z
# 2    2018-07-09T00:53:23.274Z
# 3    2018-07-09T00:53:23.313Z
# 4    2018-09-02T22:52:06.669Z
# ..                        ...
# 878  2017-12-23T20:31:53.214Z
# 879  2017-12-23T20:31:52.960Z
# 890  2017-12-23T20:50:53.374Z
# 891  2017-12-23T20:50:53.262Z
# 920  2017-12-23T20:31:47.966Z
#
#                                        product_api_url  \
# 0    http://makeup-api.herokuapp.com/api/v1/product...
# 1    http://makeup-api.herokuapp.com/api/v1/product...
# 2    http://makeup-api.herokuapp.com/api/v1/product...
# 3    http://makeup-api.herokuapp.com/api/v1/product...
# 4    http://makeup-api.herokuapp.com/api/v1/product...
# ..                                                 ...
# 878  http://makeup-api.herokuapp.com/api/v1/product...
# 879  http://makeup-api.herokuapp.com/api/v1/product...
# 890  http://makeup-api.herokuapp.com/api/v1/product...
# 891  http://makeup-api.herokuapp.com/api/v1/product...
# 920  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                     api_featured_image  \
# 0    //s3.amazonaws.com/donovanbailey/products/api_...
# 1    //s3.amazonaws.com/donovanbailey/products/api_...
# 2    //s3.amazonaws.com/donovanbailey/products/api_...
# 3    //s3.amazonaws.com/donovanbailey/products/api_...
# 4    //s3.amazonaws.com/donovanbailey/products/api_...
# ..                                                 ...
# 878  //s3.amazonaws.com/donovanbailey/products/api_...
# 879  //s3.amazonaws.com/donovanbailey/products/api_...
# 890  //s3.amazonaws.com/donovanbailey/products/api_...
# 891  //s3.amazonaws.com/donovanbailey/products/api_...
# 920  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                         product_colors  preco_acima_media  \
# 0    [{'hex_value': '#B28378', 'colour_name': 'BFF ...              False
# 1    [{'hex_value': '#b72227', 'colour_name': "Bee'...              False
# 2    [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 3    [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...              False
# 4    [{'hex_value': '#CB4975', 'colour_name': 'Babs...               True
# ..                                                 ...                ...
# 878                                                 []              False
# 879                                                 []              False
# 890  [{'hex_value': '#000000', 'colour_name': 'Blac...              False
# 891                                                 []              False
# 920  [{'hex_value': '#000000', 'colour_name': 'Blac...              False
#
#      preco_br
# 0     24.9000
# 1     27.3900
# 2     27.3900
# 3     59.7600
# 4    129.4800
# ..        ...
# 878   34.8102
# 879   34.8102
# 890   67.1802
# 891   34.8102
# 920   54.7302
#
# [591 rows x 18 columns]

# %%
True + True
# Out:
# 2

# %%
df = pd.read_csv('produtos.csv')

df['rating'].isna().sum()
# Out:
# 591

# %%
df.isna().sum()
# Out:
# id                      0
# brand                  12
# name                    0
# price                  14
# price_sign            563
# currency              563
# image_link              0
# product_link            0
# website_link            0
# description            25
# rating                591
# category              424
# product_type            0
# tag_list                0
# created_at              0
# updated_at              0
# product_api_url         0
# api_featured_image      0
# product_colors          0
# dtype: int64

# %%
df.shape
# Out:
# (931, 19)

# %%
notas_provas.dropna()
# Out:
#   nome  nota
# 0    A  85.0
# 2    C  95.0
# 3    D  78.0

# %% [markdown]
# ## Concat
# É uma funcão para **juntar** dataframes

# %%
df1 = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8 ,9]
})


df2 = pd.DataFrame({
    'b': [1, 2, 3],
    'c': [4, 5, 6],
    'd': [7, 8 ,9]
})

display(df1)
display(df2)
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#    b  c  d
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df3 = pd.concat([df1, df2])
df3
# Out:
#      a  b  c    d
# 0  1.0  4  7  NaN
# 1  2.0  5  8  NaN
# 2  3.0  6  9  NaN
# 0  NaN  1  4  7.0
# 1  NaN  2  5  8.0
# 2  NaN  3  6  9.0

# %%
df3.loc[0]
# Out:
#      a  b  c    d
# 0  1.0  4  7  NaN
# 0  NaN  1  4  7.0

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#    a  b  c  b  c  d
# 0  1  4  7  1  4  7
# 1  2  5  8  2  5  8
# 2  3  6  9  3  6  9

# %%
display(df1.loc[0])
display(df2.loc[0])
# Out:
# a    1
# b    4
# c    7
# Name: 0, dtype: int64
# b    1
# c    4
# d    7
# Name: 0, dtype: int64

# %% [markdown]
# ## Merge
# Permite o **cruzamento** de bases de dados
#
# <img src="https://community.qlik.com/legacyfs/online/87693_all-joins.png" width=450>

# %%
df4 = pd.DataFrame({
    'pais': ['br', 'pt', 'it'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})

df5 = pd.DataFrame({
    'pais': ['br', 'pt', 'ar'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})
display(df4)
display(df5)
# Out:
#   pais  valor1  valor2
# 0   br       1       3
# 1   pt       2       4
# 2   it       3       5
#   pais  valor1  valor2
# 0   br       1       3
# 1   pt       2       4
# 2   ar       3       5

# %%
df4.merge(df5, how='inner', on='pais')
# Out:
#   pais  valor1_x  valor2_x  valor1_y  valor2_y
# 0   br         1         3         1         3
# 1   pt         2         4         2         4

# %%
df4.merge(df5, how='left', on='pais')
# Out:
#   pais  valor1_x  valor2_x  valor1_y  valor2_y
# 0   br         1         3       1.0       3.0
# 1   pt         2         4       2.0       4.0
# 2   it         3         5       NaN       NaN

# %%
df4.merge(df5, how='outer', on='pais')
# Out:
#   pais  valor1_x  valor2_x  valor1_y  valor2_y
# 0   ar       NaN       NaN       3.0       5.0
# 1   br       1.0       3.0       1.0       3.0
# 2   it       3.0       5.0       NaN       NaN
# 3   pt       2.0       4.0       2.0       4.0

# %% [markdown]
# Com colunas diferentes

# %%
df4 = pd.DataFrame({
    'country': ['br', 'pt', 'it'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})

df5 = pd.DataFrame({
    'pais': ['br', 'pt', 'ar'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})
display(df4)
display(df5)
# Out:
#   country  valor1  valor2
# 0      br       1       3
# 1      pt       2       4
# 2      it       3       5
#   pais  valor1  valor2
# 0   br       1       3
# 1   pt       2       4
# 2   ar       3       5

# %%
df4.merge(df5, how='inner', left_on='country', right_on='pais')
# Out:
#   country  valor1_x  valor2_x pais  valor1_y  valor2_y
# 0      br         1         3   br         1         3
# 1      pt         2         4   pt         2         4

# %% [markdown]
# ## Join
# A juncão é baseada nos índices (definidos por set_index)

# %%
df4 = pd.DataFrame({
    'pais': ['br', 'pt', 'it'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})

df5 = pd.DataFrame({
    'pais': ['br', 'pt', 'ar'],
    'valor1': [1, 2, 3],
    'valor2': [3, 4, 5]
})
display(df4)
display(df5)
# Out:
#   pais  valor1  valor2
# 0   br       1       3
# 1   pt       2       4
# 2   it       3       5
#   pais  valor1  valor2
# 0   br       1       3
# 1   pt       2       4
# 2   ar       3       5

# %%
df4.join(df5, lsuffix='_esq', rsuffix='_dir')
# Out:
#   pais_esq  valor1_esq  valor2_esq pais_dir  valor1_dir  valor2_dir
# 0       br           1           3       br           1           3
# 1       pt           2           4       pt           2           4
# 2       it           3           5       ar           3           5

# %% [markdown]
# ### Group By

# %%
df.head()
# Out:
#      id      brand                  name  price price_sign currency  \
# 0  1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1  1047  colourpop           Blotted Lip    5.5          $      CAD
# 2  1046  colourpop           Lippie Stix    5.5          $      CAD
# 3  1045  colourpop  No Filter Foundation   12.0          $      CAD
# 4  1044      boosh              Lipstick   26.0          $      CAD
#
#                                           image_link  \
# 0  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 2  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 3  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 4  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                         product_link  \
# 0    https://colourpop.com/collections/lippie-pencil
# 1  https://colourpop.com/collections/lippie-stix?...
# 2      https://colourpop.com/collections/lippie-stix
# 3  https://colourpop.com/products/no-filter-matte...
# 4               https://www.boosh.ca/collections/all
#
#                                         website_link  \
# 0                              https://colourpop.com
# 1                              https://colourpop.com
# 2                              https://colourpop.com
# 3  https://colourpop.com/products/no-filter-matte...
# 4                              https://www.boosh.ca/
#
#                                          description  rating  category  \
# 0  Lippie Pencil A long-wearing and high-intensit...     NaN    pencil
# 1  Blotted Lip Sheer matte lipstick that creates ...     NaN  lipstick
# 2  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  lipstick
# 3  Developed for the Selfie Age, our buildable fu...     NaN    liquid
# 4  All of our products are free from lead and hea...     NaN  lipstick
#
#   product_type                      tag_list                created_at  \
# 0    lip_liner     ['cruelty free', 'Vegan']  2018-07-08T23:45:08.056Z
# 1     lipstick     ['cruelty free', 'Vegan']  2018-07-08T22:01:20.178Z
# 2     lipstick     ['cruelty free', 'Vegan']  2018-07-08T21:47:49.858Z
# 3   foundation     ['cruelty free', 'Vegan']  2018-07-08T18:22:25.273Z
# 4     lipstick  ['Chemical Free', 'Organic']  2018-07-08T17:32:28.088Z
#
#                  updated_at  \
# 0  2018-07-09T00:53:23.301Z
# 1  2018-07-09T00:53:23.287Z
# 2  2018-07-09T00:53:23.274Z
# 3  2018-07-09T00:53:23.313Z
# 4  2018-09-02T22:52:06.669Z
#
#                                      product_api_url  \
# 0  http://makeup-api.herokuapp.com/api/v1/product...
# 1  http://makeup-api.herokuapp.com/api/v1/product...
# 2  http://makeup-api.herokuapp.com/api/v1/product...
# 3  http://makeup-api.herokuapp.com/api/v1/product...
# 4  http://makeup-api.herokuapp.com/api/v1/product...
#
#                                   api_featured_image  \
# 0  //s3.amazonaws.com/donovanbailey/products/api_...
# 1  //s3.amazonaws.com/donovanbailey/products/api_...
# 2  //s3.amazonaws.com/donovanbailey/products/api_...
# 3  //s3.amazonaws.com/donovanbailey/products/api_...
# 4  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                       product_colors
# 0  [{'hex_value': '#B28378', 'colour_name': 'BFF ...
# 1  [{'hex_value': '#b72227', 'colour_name': "Bee'...
# 2  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...
# 3  [{'hex_value': '#F2DEC3', 'colour_name': 'Fair...
# 4  [{'hex_value': '#CB4975', 'colour_name': 'Babs...

# %%
df[['brand', 'price']].groupby(['brand']).sum()
# Out:
#                             price
# brand
# almay                      177.26
# alva                         9.95
# anna sui                   132.00
# annabelle                  107.86
# benefit                   1252.00
# boosh                       26.00
# burt's bees                 19.98
# butter london               50.96
# c'est moi                    0.00
# cargo cosmetics            585.00
# china glaze                  8.00
# clinique                  2094.35
# coastal classic creation     0.00
# colourpop                   28.00
# covergirl                  522.96
# dalish                      22.00
# deciem                      13.60
# dior                      2024.50
# dr. hauschka               407.00
# e.l.f.                     182.73
# essie                       40.00
# fenty                      116.00
# glossier                   150.00
# green people                 0.00
# iman                         0.00
# l'oreal                    638.11
# lotus cosmetics usa          0.00
# maia's mineral galaxy        0.00
# marcelle                   218.85
# marienatie                   0.00
# maybelline                 601.46
# milani                     117.87
# mineral fusion             203.00
# misa                         9.39
# mistura                     56.49
# moov                        44.97
# nudus                        0.00
# nyx                       1380.58
# orly                        42.98
# pacifica                   330.96
# penny lane organics          0.00
# physicians formula         740.17
# piggy paint                 11.99
# pure anada                 227.99
# rejuva minerals              0.00
# revlon                     391.31
# sally b's skin yummies       0.00
# salon perfect                6.99
# sante                      132.54
# sinful colours               2.99
# smashbox                  1373.00
# stila                      184.99
# suncoat                     96.04
# w3llpeople                   0.00
# wet n wild                  51.68
# zorah                       51.00
# zorah biocosmetiques         0.00

# %%
df[df['brand'] == 'almay']['price'].mean()
# Out:
# 12.661428571428575

# %%
(
df[['brand', 'price', 'rating']]
    .groupby(['brand'])
    .agg({
        'price': ['mean', 'min', 'max'],
        'rating': ['mean', 'count']
    })
)
# Out:
#                               price                  rating
#                                mean    min    max      mean count
# brand
# almay                     12.661429   8.99  17.29  4.241667    12
# alva                       9.950000   9.95   9.95       NaN     0
# anna sui                  22.000000  10.00  28.00       NaN     0
# annabelle                  9.805455   6.99  11.99  4.966667     6
# benefit                   30.536585  16.00  75.00       NaN     0
# boosh                     26.000000  26.00  26.00       NaN     0
# burt's bees                9.990000   9.99   9.99  4.100000     2
# butter london             25.480000  22.00  28.96  5.000000     1
# c'est moi                  0.000000   0.00   0.00       NaN     0
# cargo cosmetics           29.250000  19.00  42.00  4.845455    11
# china glaze                8.000000   8.00   8.00  4.700000     1
# clinique                  22.764674   8.50  39.00       NaN     0
# coastal classic creation   0.000000   0.00   0.00       NaN     0
# colourpop                  7.000000   5.00  12.00       NaN     0
# covergirl                  9.684444   4.49  15.99  4.427273    33
# dalish                    22.000000  22.00  22.00  3.800000     1
# deciem                     6.800000   6.70   6.90       NaN     0
# dior                      27.358108   0.00  77.00       NaN     0
# dr. hauschka              33.916667  22.00  45.00  4.670000    10
# e.l.f.                     6.767778   3.99  13.99  4.381818    22
# essie                     10.000000  10.00  10.00  3.550000     4
# fenty                     23.200000  18.00  34.00       NaN     0
# glossier                  25.000000  20.00  32.00       NaN     0
# green people               0.000000   0.00   0.00       NaN     0
# iman                            NaN    NaN    NaN       NaN     0
# l'oreal                   13.871957   7.79  29.99  4.323333    30
# lotus cosmetics usa        0.000000   0.00   0.00       NaN     0
# maia's mineral galaxy      0.000000   0.00   0.00       NaN     0
# marcelle                  14.590000  10.99  22.99  4.250000     6
# marienatie                 0.000000   0.00   0.00       NaN     0
# maybelline                11.138148   4.49  18.49  4.082609    46
# milani                     9.066923   3.99  12.99  4.480000    10
# mineral fusion            25.375000  10.00  37.00  4.180000     5
# misa                       9.390000   9.39   9.39  5.000000     1
# mistura                   56.490000  56.49  56.49  2.600000     1
# moov                      14.990000  14.99  14.99  2.500000     2
# nudus                      0.000000   0.00   0.00       NaN     0
# nyx                        8.418171   0.00  20.00  4.318182    11
# orly                      10.745000   8.00  13.49  3.666667     3
# pacifica                  25.458462  14.00  60.00  4.466667    12
# penny lane organics        0.000000   0.00   0.00       NaN     0
# physicians formula        17.213256   8.99  29.99  4.307692    39
# piggy paint               11.990000  11.99  11.99  4.300000     1
# pure anada                14.249375   8.00  25.99  4.460000    15
# rejuva minerals            0.000000   0.00   0.00       NaN     0
# revlon                    13.493448   6.99  19.99  4.456522    23
# sally b's skin yummies     0.000000   0.00   0.00       NaN     0
# salon perfect              6.990000   6.99   6.99       NaN     0
# sante                     22.090000  17.29  27.49  4.083333     6
# sinful colours             2.990000   2.99   2.99  4.300000     1
# smashbox                  29.847826  18.00  55.00       NaN     0
# stila                     46.247500  36.00  51.00       NaN     0
# suncoat                   16.006667   8.29  22.49  3.766667     6
# w3llpeople                 0.000000   0.00   0.00       NaN     0
# wet n wild                 4.306667   1.99   6.99  4.666667     9
# zorah                     25.500000  24.00  27.00  4.050000     2
# zorah biocosmetiques       0.000000   0.00   0.00       NaN     0

# %% [markdown]
# #### Trabalhar com datas

# %%
dados = {
    'data': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
    'produto': ['A', 'B', 'A', 'B'],
    'qtde': [20, 35, 25, 40]
}

df_temp = pd.DataFrame(dados)
df_temp
# Out:
#          data produto  qtde
# 0  2024-01-01       A    20
# 1  2024-01-01       B    35
# 2  2024-01-02       A    25
# 3  2024-01-02       B    40

# %%
df_temp.dtypes
# Out:
# data       object
# produto    object
# qtde        int64
# dtype: object

# %%
# https://docs.python.org/pt-br/3.10/library/datetime.html#strftime-and-strptime-format-codes

# %%
df_temp['data_tipada'] = pd.to_datetime(df_temp['data'], format='%Y-%m-%d')
df_temp.head()
# Out:
#          data produto  qtde data_tipada
# 0  2024-01-01       A    20  2024-01-01
# 1  2024-01-01       B    35  2024-01-01
# 2  2024-01-02       A    25  2024-01-02
# 3  2024-01-02       B    40  2024-01-02

# %%
df_temp.dtypes
# Out:
# data                   object
# produto                object
# qtde                    int64
# data_tipada    datetime64[ns]
# dtype: object

# %%
df_temp['mes'] = df_temp['data_tipada'].dt.month
df_temp
# Out:
#          data produto  qtde data_tipada  mes
# 0  2024-01-01       A    20  2024-01-01    1
# 1  2024-01-01       B    35  2024-01-01    1
# 2  2024-01-02       A    25  2024-01-02    1
# 3  2024-01-02       B    40  2024-01-02    1

# %%
df_temp['dia'] = df_temp['data_tipada'].dt.day
df_temp
# Out:
#          data produto  qtde data_tipada  mes  dia
# 0  2024-01-01       A    20  2024-01-01    1    1
# 1  2024-01-01       B    35  2024-01-01    1    1
# 2  2024-01-02       A    25  2024-01-02    1    2
# 3  2024-01-02       B    40  2024-01-02    1    2

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DatetimeIndex.dayofweek.html

# %%
df_temp['dia_semana'] = df_temp['data_tipada'].dt.dayofweek
df_temp
# Out:
#          data produto  qtde data_tipada  mes  dia  dia_semana
# 0  2024-01-01       A    20  2024-01-01    1    1           0
# 1  2024-01-01       B    35  2024-01-01    1    1           0
# 2  2024-01-02       A    25  2024-01-02    1    2           1
# 3  2024-01-02       B    40  2024-01-02    1    2           1

# %% [markdown]
# #### Dados Faltantes

# %%
notas_provas = pd.DataFrame({
    'nome': ['A', 'B', 'C', 'D', 'E'],
    'nota': [85, np.nan, 95, 78, np.nan]
})
notas_provas
# Out:
#   nome  nota
# 0    A  85.0
# 1    B   NaN
# 2    C  95.0
# 3    D  78.0
# 4    E   NaN

# %%
notas_provas.fillna(0)
# Out:
#   nome  nota
# 0    A  85.0
# 1    B   0.0
# 2    C  95.0
# 3    D  78.0
# 4    E   0.0

# %%
media_notas = notas_provas['nota'].mean()
novas_notas = notas_provas.fillna(media_notas)
novas_notas
# Out:
#   nome  nota
# 0    A  85.0
# 1    B  86.0
# 2    C  95.0
# 3    D  78.0
# 4    E  86.0

# %%
novas_notas['nota'].mean()
# Out:
# 86.0
