# %% [markdown]
# # Apresentações
#
# Muito prazer professor(es)
# - [Thiago Kuma](https://docs.google.com/presentation/d/1-Uezm34ieQ9gWfFR2mwflivI_qcxBZJtNp2OREoBQx4/edit?usp=sharing)

# %% [markdown]
# Pesquisa 1 - https://mentimeter.com <h3>44 14 &nbsp;&nbsp; 49 72<h3>
#
# <img width="300" weight="300"
# src=" data:image/png;base64,..." />

# %% [markdown]
# ____
